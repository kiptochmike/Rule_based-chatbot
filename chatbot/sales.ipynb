# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('stock sheet.csv')
df.head(10)
# Out:
#          Item No.                                Item Description  GroupCode   \
# 0  PSR-LRD-BST-035                        245/70R16 BST DUELER 697        PSR
# 1  PSR-LRD-ARM-013          185/70R14 ARMSTRONG 88H BLU-TRAC PC(T)        PSR
# 2  PSR-HRD-ARM-008       195R15C ARMSTRONG 104R TRU-TRAC VAN TL(T)        PSR
# 3  PSR-LRD-ARM-012          195/65R15 ARMSTRONG 91V BLU-TRAC PC(T)        PSR
# 4  PSR-LRD-BST-037                        265/70R16 BST DUELER 697        PSR
# 5  PSR-HRD-BST-003                    265/65R17 BST DUELER A/T 697        PSR
# 6  PSR-LRD-ARM-015   245/70R16 ARMSTRONG 111T XL TRU-TRAC AT TL(T)        PSR
# 7  PSR-HRD-ARM-017  235/85R16 ARMSTRONG 120/116S TRU-TRAC AT TL(T)        PSR
# 8  PSR-HRD-ARM-006   265/65R17 ARMSTRONG 116T XL TRU-TRAC AT TL(T)        PSR
# 9  TBR-TBR-BST-044              315/80R22.5 BST 154M156L G582 - OE        TBR
#
#         Brand  Rim Size    Tyre Size    Tyre Pattern  SlowMoving   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item No.           243 non-null    object
#  1   Item Description   243 non-null    object
#  2   GroupCode          243 non-null    object
#  3   Brand              243 non-null    object
#  4   Rim Size           243 non-null    object
#  5   Tyre Size          243 non-null    object
#  6   Tyre Pattern       184 non-null    object
#  7   SlowMoving         243 non-null    object
#  8   HeadOffice         243 non-null    int64
#  9   Mombasa            243 non-null    int64
#  10  MSA Road           243 non-null    int64
#  11  Total              243 non-null    int64
#  12  List Price         243 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 24.8+ KB

# %%
# Print column names
print(df.columns)
# Out:
# Index(['Item No. ', 'Item Description ', 'GroupCode ', 'Brand ', 'Rim Size ',
#        'Tyre Size ', 'Tyre Pattern ', 'SlowMoving ', 'HeadOffice ', 'Mombasa ',
#        'MSA Road ', 'Total ', 'List Price '],
#       dtype='object')
